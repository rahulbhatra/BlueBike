# %%
install.packages("tidyverse")
install.packages("lubridate")
install.packages("ggcorrplot")
install.packages("lattice")
install.packages("psych")
install.packages("reshape2")
install.packages("DataExplorer")
install.packages("car")
install.packages("caret")
install.packages("cowplot")
install.packages("caTools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘Rcpp’, ‘reshape2’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘mnormt’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘htmlwidgets’, ‘igraph’, ‘gridExtra’, ‘networkD3’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘future.apply’, ‘progressr’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘pROC’, ‘recipes’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘bitops’

# %%
install.packages("rpart.plot")
install.packages("e1071")
install.packages("leaps")
install.packages("rpart")
install.packages("randomForest")
install.packages("caTools")
install.packages("caTools")
install.packages("caTools")
install.packages("caTools")
install.packages("caTools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
library(lubridate)
library(ggcorrplot)
library(lattice)
library(psych)
library(DataExplorer)
library(reshape2)
library(car)
library(caret)
library(cowplot)
library(caTools)
library(e1071)
library(rpart)
par(mfrow=c(1,1))

# %%
install.packages("leaps")
install.packages("randomForest")
install.packages("rpart.plot")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# library(rpart.plot)
library(leaps)
library(randomForest)
library(rpart.plot)
# Out:
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:psych’:
#
#     outlier
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %%
b <- read_csv("data.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 2319 Columns: 37
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (6): name, preciptype, conditions, description, icon, stations
# dbl  (28): ...1, totalTrips, totalCrimes, X, tempmax, tempmin, temp, feelsli...
# dttm  (2): sunrise, sunset
# date  (1): date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(b)
# Out:
#   ...1 date       totalTrips totalCrimes X   name   tempmax tempmin temp
# 1 1    2015-06-15 1496       239         166 boston 17.2    12.2    13.9
# 2 2    2015-06-16 5119       251         167 boston 21.0    13.4    16.4
# 3 3    2015-06-17 6246       226         168 boston 20.5    16.6    18.4
# 4 4    2015-06-18 6124       285         169 boston 23.3    13.7    18.3
# 5 5    2015-06-19 5803       276         170 boston 28.3    17.2    20.8
# 6 6    2015-06-20 4797       246         171 boston 23.4    14.8    18.0
#   feelslikemax ⋯ solarenergy uvindex severerisk sunrise
# 1 17.2         ⋯ 10.4        4       NA         2015-06-15 05:06:51
# 2 21.0         ⋯ 18.8        7       NA         2015-06-16 05:06:53
# 3 20.5         ⋯ 24.2        9       NA         2015-06-17 05:06:56
# 4 23.3         ⋯ 25.1        9       NA         2015-06-18 05:07:02
# 5 28.1         ⋯ 21.7        7       NA         2015-06-19 05:07:09
# 6 23.4         ⋯ 25.4        8       NA         2015-06-20 05:07:19
#   sunset              moonphase conditions
# 1 2015-06-15 20:22:40 1.00      Rain, Overcast
# 2 2015-06-16 20:23:03 1.00      Rain, Overcast
# 3 2015-06-17 20:23:24 0.00      Partially cloudy
# 4 2015-06-18 20:23:44 0.02      Partially cloudy
# 5 2015-06-19 20:24:01 0.05      Partially cloudy
# 6 2015-06-20 20:24:16 0.08      Partially cloudy
#   description                                              icon
# 1 Cloudy skies throughout the day with rain.               rain
# 2 Cloudy skies throughout the day with early morning rain. rain
# 3 Partly cloudy throughout the day.                        partly-cloudy-day
# 4 Partly cloudy throughout the day.                        partly-cloudy-day
# 5 Partly cloudy throughout the day.                        partly-cloudy-day
# 6 Partly cloudy throughout the day.                        partly-cloudy-day
#   stations
# 1 KOWD,72509854704,KBED,KBOS,72509014739,72505914702
# 2 KOWD,72509854704,KBED,KBOS,72509014739,72505914702
# 3 KOWD,72509854704,KBED,KBOS,72509014739,72505914702
# 4 KOWD,72509854704,KBED,KBOS,72509014739,72505914702
# 5 KOWD,72509854704,KBED,KBOS,72509014739,72505914702
# 6 KOWD,72509854704,KBED,KBOS,72509014739,72505914702

# %%
#format the Month and day as a number that can be ordered as a factor
# b$date <- as.character(b$date, format = "%e/%d/%y")
# create month day as a number that we can order as a factor

b$Year <- as.factor(as.character(b$date, format = "%Y"))
b$Month <- as.character(b$date, format = "%m")
b$DayName <- as.character(b$date, format = "%u")
b$Day <- as.character(b$date, format = "%d")


# b$timestamp <- NULL
b$date <- NULL

head(b, 5)
# Out:
#   ...1 totalTrips totalCrimes X   name   tempmax tempmin temp feelslikemax
# 1 1    1496       239         166 boston 17.2    12.2    13.9 17.2
# 2 2    5119       251         167 boston 21.0    13.4    16.4 21.0
# 3 3    6246       226         168 boston 20.5    16.6    18.4 20.5
# 4 4    6124       285         169 boston 23.3    13.7    18.3 23.3
# 5 5    5803       276         170 boston 28.3    17.2    20.8 28.1
#   feelslikemin ⋯ sunset              moonphase conditions
# 1 12.2         ⋯ 2015-06-15 20:22:40 1.00      Rain, Overcast
# 2 13.4         ⋯ 2015-06-16 20:23:03 1.00      Rain, Overcast
# 3 16.6         ⋯ 2015-06-17 20:23:24 0.00      Partially cloudy
# 4 13.7         ⋯ 2015-06-18 20:23:44 0.02      Partially cloudy
# 5 17.2         ⋯ 2015-06-19 20:24:01 0.05      Partially cloudy
#   description                                              icon
# 1 Cloudy skies throughout the day with rain.               rain
# 2 Cloudy skies throughout the day with early morning rain. rain
# 3 Partly cloudy throughout the day.                        partly-cloudy-day
# 4 Partly cloudy throughout the day.                        partly-cloudy-day
# 5 Partly cloudy throughout the day.                        partly-cloudy-day
#   stations                                           Year Month DayName Day
# 1 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 06    1       15
# 2 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 06    2       16
# 3 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 06    3       17
# 4 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 06    4       18
# 5 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 06    5       19

# %%
b$Month <- factor(
  b$Month, levels = c("01","02","03","04","05","06","07","08","09","10","11","12"),
  labels = c('January','February', 'March', 'April',
             'May', 'June', 'July', 'August',
             'September','October', 'November', 'December'),
  ordered = TRUE)

#### ---  Day ----#####
b$DayName <- factor(
  b$DayName,levels = c(1,2,3,4,5,6,7),
  labels = c('Monday','Tuesday','Wednesday','Thursday',
             'Friday', 'Saturday','Sunday'),
  ordered = TRUE)

# %%
# pal = c("olivedrab3", 'yellow', 'orange', 'grey50')
#####   Rentals by Season & Temperature    #####
options(repr.plot.width=12, repr.plot.height=8)
ggplot(b, aes(temp, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 20) +
# + scale_color_manual(values = pal) 

  labs(title = "Rentals by Month & Temperature", x = "Temperature Celsius", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma())
# Out:
# plot without title

# %%
#####   Rentals by Month & Temperature & Year   #####
ggplot(b, aes(temp, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 10) + 
  # scale_color_manual(values = pal) +
  labs(title = "Rentals by Month, Temperature & Year", x = "Temperature Celsius", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma()) +
  facet_grid(~Year)
# Out:
# plot without title

# %%
#####   Rentals by Humidity & Month     #####
a1 = ggplot(b, aes(humidity, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 10) + 
  # scale_color_manual(values = pal) 
   facet_grid(~Year) +
  labs(title = "Rentals by Humidity & Month", x = "Humidity", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma()) + 
  theme(legend.position="bottom")
  plot_grid(a1)
# Out:
# plot without title

# %%
####    Rentals by Windspeed & Month    #####
b1 = ggplot(b, aes(windspeed, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 10) + 
  # scale_color_manual(values = pal) + 
  facet_grid(~Year) +
  labs(title = "Rentals by Windspeed & Month", x = "Wind Speed", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma()) + 
  theme(legend.position="bottom")
options(repr.plot.width=16, repr.plot.height=8)
plot_grid(b1)
# Out:
# plot without title

# %%
####    Rentals by Visibility & Month    #####
c1 = ggplot(b, aes(visibility, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 10) + 
  # scale_color_manual(values = pal) + 
  facet_grid(~Year) +
  labs(title = "Rentals by Visibility & Month", x = "Visibility", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma()) + 
  theme(legend.position="bottom")
options(repr.plot.width=16, repr.plot.height=8)
plot_grid(c1)
# Out:
# plot without title

# %%
####    Rentals by feelsLike & Month    #####
c1 = ggplot(b, aes(feelslike, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 10) + 
  # scale_color_manual(values = pal) + 
  facet_grid(~Year) +
  labs(title = "Rentals by Feels Like Temp & Month", x = "Feels Like Temp", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma()) + 
  theme(legend.position="bottom")
options(repr.plot.width=16, repr.plot.height=8)
plot_grid(c1)
# Out:
# plot without title

# %%
####    Rentals by uvindex & Month    #####
c1 = ggplot(b, aes(uvindex, totalTrips, color = Month)) + geom_point() +
  theme_bw(base_size = 10) + 
  # scale_color_manual(values = pal) + 
  facet_grid(~Year) +
  labs(title = "Rentals by uvindex & Month", x = "uvindex", y = "Total Rentals") +
  scale_y_continuous(labels = scales::label_comma()) + 
  theme(legend.position="bottom")
options(repr.plot.width=16, repr.plot.height=8)
plot_grid(c1)
# Out:
# plot without title

# %%
# ----   Rentals & Temperature by Weather 
# w = c('skyblue1','skyblue2','skyblue3','skyblue4','grey40')
ggplot(b, aes(temp, totalTrips, color = conditions)) + 
  geom_jitter(width = 0.25, show.legend = F) + 
  # scale_color_manual(values = w) +
  labs(y="Count of Rentals", title = "Rentals & Temperature by Weather Conditions") + 
  facet_grid(~conditions) + theme_bw(base_size = 10)
# Out:
# plot without title

# %%
boxplot(totalTrips ~ DayName, data = b, frame = F, col = "grey40")
# Out:
# plot without title

# %%
# par(mfrow=c(1,2))
options(repr.plot.width=16, repr.plot.height=6)
boxplot(totalTrips ~ Month, data = b, frame = F, col = "grey40")
# Out:
# plot without title

# %%
boxplot(totalTrips ~ conditions, data = b, frame = F,col = "grey40")
# Out:
# plot without title

# %% [markdown]
# ANOVA - differences in Means

# %%
aov.M <- aov(totalTrips ~ Month, data = b); summary(aov.M);
aov.D <- aov(totalTrips ~ Day, data = b); summary(aov.D);
aov.DN <- aov(totalTrips ~ DayName, data = b); summary(aov.DN);
aov.C <- aov(totalTrips ~ conditions, data = b); summary(aov.C);

# aov.M <- aov(totalTrips ~ Month, data = b); summary(aov.M);
# aov.M <- aov(totalTrips ~ Month, data = b); summary(aov.M);
# aov.M <- aov(totalTrips ~ Month, data = b); summary(aov.M);

# aov.S <- aov(Rentals ~ Season, data = b); summary(aov.S);
# aov.M <- aov(Rentals ~ Month, data = b); summary(aov.M);
# aov.H <- aov(Rentals ~ Hour, data = b); summary(aov.H)
# Out:
#               Df    Sum Sq   Mean Sq F value Pr(>F)
# Month         11 1.871e+10 1.701e+09     158 <2e-16 ***
# Residuals   2307 2.483e+10 1.076e+07
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#               Df    Sum Sq  Mean Sq F value Pr(>F)
# Day           30 9.361e+07  3120481   0.164      1
# Residuals   2288 4.344e+10 18987480
#               Df    Sum Sq  Mean Sq F value Pr(>F)
# DayName        6 2.148e+08 35796148    1.91 0.0756 .
# Residuals   2312 4.332e+10 18737972
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#               Df    Sum Sq   Mean Sq F value Pr(>F)
# conditions    13 3.283e+09 252574045   14.46 <2e-16 ***
# Residuals   2305 4.025e+10  17463560
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
## Post Hoc test to identify which  group is different
TukeyHSD(aov.M , which = "Month");
TukeyHSD(aov.D, which = "Day");
TukeyHSD(aov.DN, which = "DayName");
TukeyHSD(aov.C, which = "conditions")
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula
# Saturday-Tuesday    -55.945436 -1048.8845  936.9936 0.9999982
# Sunday-Tuesday     -668.557331 -1669.1527  332.0381 0.4331029
# Thursday-Wednesday  -26.493066 -1018.6886  965.7025 1.0000000
# Friday-Wednesday      2.341126  -987.6473  992.3295 1.0000000
# Saturday-Wednesday -228.899982 -1221.8390  764.0391 0.9936786
# Sunday-Wednesday   -841.511877 -1842.1073  159.0835 0.1663187
# Friday-Thursday      28.834191  -958.9019 1016.5703 1.0000000
# Saturday-Thursday  -202.406916 -1193.1003  788.2865 0.9967401
# Sunday-Thursday    -815.018811 -1813.3858  183.3482 0.1950843
# Saturday-Friday    -231.241107 -1219.7240  757.2418 0.9931559
# Sunday-Friday      -843.853002 -1840.0265  152.3205 0.1597179
# Sunday-Saturday    -612.611895 -1611.7178  386.4940 0.5417505
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = totalTrips ~ conditions, data = b)
#
# $conditions
#                                                                                                                                diff
# Overcast-Clear                                                                                                          -622.366736
# Partially cloudy-Clear                                                                                                  1129.489712
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Clear                                                            -910.607477
# Rain, Overcast-Clear                                                                                                    -375.919672
# Rain, Partially cloudy-Clear                                                                                             914.581005
# Snow, Overcast-Clear                                                                                                   -3833.750334
# Snow, Partially cloudy-Clear                                                                                           -3814.081161
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Clear                                                        -3874.107477
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Clear                                                             -2122.607477
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Clear                                                     -1225.607477
# Snow, Rain, Ice, Overcast-Clear                                                                                        -2559.607477
# Snow, Rain, Overcast-Clear                                                                                             -3794.431006
# Snow, Rain, Partially cloudy-Clear                                                                                     -3804.216172
# Partially cloudy-Overcast                                                                                               1751.856448
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Overcast                                                         -288.240741
# Rain, Overcast-Overcast                                                                                                  246.447064
# Rain, Partially cloudy-Overcast                                                                                         1536.947741
# Snow, Overcast-Overcast                                                                                                -3211.383598
# Snow, Partially cloudy-Overcast                                                                                        -3191.714425
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Overcast                                                     -3251.740741
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Overcast                                                          -1500.240741
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Overcast                                                   -603.240741
# Snow, Rain, Ice, Overcast-Overcast                                                                                     -1937.240741
# Snow, Rain, Overcast-Overcast                                                                                          -3172.064270
# Snow, Rain, Partially cloudy-Overcast                                                                                  -3181.849436
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Partially cloudy                                                -2040.097189
# Rain, Overcast-Partially cloudy                                                                                        -1505.409384
# Rain, Partially cloudy-Partially cloudy                                                                                 -214.908707
# Snow, Overcast-Partially cloudy                                                                                        -4963.240046
# Snow, Partially cloudy-Partially cloudy                                                                                -4943.570873
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Partially cloudy                                             -5003.597189
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Partially cloudy                                                  -3252.097189
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Partially cloudy                                          -2355.097189
# Snow, Rain, Ice, Overcast-Partially cloudy                                                                             -3689.097189
# Snow, Rain, Overcast-Partially cloudy                                                                                  -4923.920718
# Snow, Rain, Partially cloudy-Partially cloudy                                                                          -4933.705884
# Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                                    534.687805
# Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                           1825.188482
# Snow, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                                  -2923.142857
# Snow, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                          -2903.473684
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy       -2963.500000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy            -1212.000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy     -315.000000
# Snow, Rain, Ice, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                       -1649.000000
# Snow, Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                            -2883.823529
# Snow, Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                    -2893.608696
# Rain, Partially cloudy-Rain, Overcast                                                                                   1290.500677
# Snow, Overcast-Rain, Overcast                                                                                          -3457.830662
# Snow, Partially cloudy-Rain, Overcast                                                                                  -3438.161489
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Overcast                                               -3498.187805
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Overcast                                                    -1746.687805
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Overcast                                             -849.687805
# Snow, Rain, Ice, Overcast-Rain, Overcast                                                                               -2183.687805
# Snow, Rain, Overcast-Rain, Overcast                                                                                    -3418.511334
# Snow, Rain, Partially cloudy-Rain, Overcast                                                                            -3428.296501
# Snow, Overcast-Rain, Partially cloudy                                                                                  -4748.331339
# Snow, Partially cloudy-Rain, Partially cloudy                                                                          -4728.662166
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Partially cloudy                                       -4788.688482
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Partially cloudy                                            -3037.188482
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Partially cloudy                                    -2140.188482
# Snow, Rain, Ice, Overcast-Rain, Partially cloudy                                                                       -3474.188482
# Snow, Rain, Overcast-Rain, Partially cloudy                                                                            -4709.012011
# Snow, Rain, Partially cloudy-Rain, Partially cloudy                                                                    -4718.797177
# Snow, Partially cloudy-Snow, Overcast                                                                                     19.669173
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Overcast                                                 -40.357143
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Overcast                                                     1711.142857
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Overcast                                             2608.142857
# Snow, Rain, Ice, Overcast-Snow, Overcast                                                                                1274.142857
# Snow, Rain, Overcast-Snow, Overcast                                                                                       39.319328
# Snow, Rain, Partially cloudy-Snow, Overcast                                                                               29.534161
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Partially cloudy                                         -60.026316
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Partially cloudy                                             1691.473684
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Partially cloudy                                     2588.473684
# Snow, Rain, Ice, Overcast-Snow, Partially cloudy                                                                        1254.473684
# Snow, Rain, Overcast-Snow, Partially cloudy                                                                               19.650155
# Snow, Rain, Partially cloudy-Snow, Partially cloudy                                                                        9.864989
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast          1751.500000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast  2648.500000
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                     1314.500000
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                            79.676471
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                    69.891304
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast        897.000000
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                          -437.000000
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                              -1671.823529
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                      -1681.608696
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                 -1334.000000
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                      -2568.823529
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                              -2578.608696
# Snow, Rain, Overcast-Snow, Rain, Ice, Overcast                                                                         -1234.823529
# Snow, Rain, Partially cloudy-Snow, Rain, Ice, Overcast                                                                 -1244.608696
# Snow, Rain, Partially cloudy-Snow, Rain, Overcast                                                                         -9.785166
#                                                                                                                                lwr
# Overcast-Clear                                                                                                          -2964.2937
# Partially cloudy-Clear                                                                                                   -283.8969
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Clear                                                           -15005.7402
# Rain, Overcast-Clear                                                                                                    -2049.1574
# Rain, Partially cloudy-Clear                                                                                             -562.9426
# Snow, Overcast-Clear                                                                                                    -9307.1946
# Snow, Partially cloudy-Clear                                                                                            -7306.8172
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Clear                                                        -13886.9075
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Clear                                                             -16217.7402
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Clear                                                     -15320.7402
# Snow, Rain, Ice, Overcast-Clear                                                                                        -16654.7402
# Snow, Rain, Overcast-Clear                                                                                              -6556.4546
# Snow, Rain, Partially cloudy-Clear                                                                                      -5970.3689
# Partially cloudy-Overcast                                                                                                -198.3123
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Overcast                                                        -14447.2755
# Rain, Overcast-Overcast                                                                                                 -1899.5309
# Rain, Partially cloudy-Overcast                                                                                          -460.1934
# Snow, Overcast-Overcast                                                                                                 -8847.3475
# Snow, Partially cloudy-Overcast                                                                                         -6934.0001
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Overcast                                                     -13354.2979
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Overcast                                                          -15659.2755
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Overcast                                                  -14762.2755
# Snow, Rain, Ice, Overcast-Overcast                                                                                     -16096.2755
# Snow, Rain, Overcast-Overcast                                                                                           -6243.5902
# Snow, Rain, Partially cloudy-Overcast                                                                                   -5730.9109
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Partially cloudy                                                -16075.4563
# Rain, Overcast-Partially cloudy                                                                                         -2562.8880
# Rain, Partially cloudy-Partially cloudy                                                                                  -923.1547
# Snow, Overcast-Partially cloudy                                                                                        -10280.8644
# Snow, Partially cloudy-Partially cloudy                                                                                 -8186.6776
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Partially cloudy                                             -14932.0765
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Partially cloudy                                                  -17287.4563
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Partially cloudy                                          -16390.4563
# Snow, Rain, Ice, Overcast-Partially cloudy                                                                             -17724.4563
# Snow, Rain, Overcast-Partially cloudy                                                                                   -7362.6316
# Snow, Rain, Partially cloudy-Partially cloudy                                                                           -6668.8584
# Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                                  -13529.2152
# Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                          -12216.7743
# Snow, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                                  -17921.5506
# Snow, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                          -17297.6686
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy       -20146.3347
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy            -21053.0285
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy    -20156.0285
# Snow, Rain, Ice, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                       -21490.0285
# Snow, Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                            -17118.3736
# Snow, Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                    -17024.6334
# Rain, Partially cloudy-Rain, Overcast                                                                                     148.7146
# Snow, Overcast-Rain, Overcast                                                                                           -8850.3432
# Snow, Partially cloudy-Rain, Overcast                                                                                   -6802.6532
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Overcast                                               -13466.9773
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Overcast                                                    -15810.5908
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Overcast                                            -14913.5908
# Snow, Rain, Ice, Overcast-Rain, Overcast                                                                               -16247.5908
# Snow, Rain, Overcast-Rain, Overcast                                                                                     -6016.4670
# Snow, Rain, Partially cloudy-Rain, Overcast                                                                             -5380.9401
# Snow, Overcast-Rain, Partially cloudy                                                                                  -10083.3611
# Snow, Partially cloudy-Rain, Partially cloudy                                                                           -8000.2300
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Partially cloudy                                       -14726.5009
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Partially cloudy                                            -17079.1513
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Partially cloudy                                    -16182.1513
# Snow, Rain, Ice, Overcast-Rain, Partially cloudy                                                                       -17516.1513
# Snow, Rain, Overcast-Rain, Partially cloudy                                                                             -7185.4460
# Snow, Rain, Partially cloudy-Rain, Partially cloudy                                                                     -6506.5803
# Snow, Partially cloudy-Snow, Overcast                                                                                   -6183.4487
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Overcast                                               -11289.1629
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Overcast                                                    -13287.2649
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Overcast                                            -12390.2649
# Snow, Rain, Ice, Overcast-Snow, Overcast                                                                               -13724.2649
# Snow, Rain, Overcast-Snow, Overcast                                                                                     -5783.7590
# Snow, Rain, Partially cloudy-Snow, Overcast                                                                             -5535.6868
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Partially cloudy                                       -10489.6114
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Partially cloudy                                            -12702.7212
# ...
# Snow, Rain, Ice, Overcast-Rain, Partially cloudy                                                                       10567.7743
# Snow, Rain, Overcast-Rain, Partially cloudy                                                                            -2232.5780
# Snow, Rain, Partially cloudy-Rain, Partially cloudy                                                                    -2931.0140
# Snow, Partially cloudy-Snow, Overcast                                                                                   6222.7871
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Overcast                                               11208.4487
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Overcast                                                    16709.5506
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Overcast                                            17606.5506
# Snow, Rain, Ice, Overcast-Snow, Overcast                                                                               16272.5506
# Snow, Rain, Overcast-Snow, Overcast                                                                                     5862.3977
# Snow, Rain, Partially cloudy-Snow, Overcast                                                                             5594.7551
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Partially cloudy                                       10369.5588
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Partially cloudy                                            16085.6686
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Partially cloudy                                    16982.6686
# Snow, Rain, Ice, Overcast-Snow, Partially cloudy                                                                       15648.6686
# Snow, Rain, Overcast-Snow, Partially cloudy                                                                             4038.2139
# Snow, Rain, Partially cloudy-Snow, Partially cloudy                                                                     3644.7374
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast         18934.3347
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast 19831.3347
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                    18497.3347
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                         10287.8014
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                 10133.1541
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast      20738.0285
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                         19404.0285
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                              12562.7266
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                      12449.4160
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                 18507.0285
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                      11665.7266
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                              11552.4160
# Snow, Rain, Overcast-Snow, Rain, Ice, Overcast                                                                         12999.7266
# Snow, Rain, Partially cloudy-Snow, Rain, Ice, Overcast                                                                 12886.4160
# Snow, Rain, Partially cloudy-Snow, Rain, Overcast                                                                       2929.9201
#                                                                                                                            p adj
# Overcast-Clear                                                                                                         0.9998073
# Partially cloudy-Clear                                                                                                 0.2893415
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Clear                                                           1.0000000
# Rain, Overcast-Clear                                                                                                   0.9999715
# Rain, Partially cloudy-Clear                                                                                           0.7165750
# Snow, Overcast-Clear                                                                                                   0.5164771
# Snow, Partially cloudy-Clear                                                                                           0.0178194
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Clear                                                        0.9908428
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Clear                                                             0.9999998
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Clear                                                     1.0000000
# Snow, Rain, Ice, Overcast-Clear                                                                                        0.9999977
# Snow, Rain, Overcast-Clear                                                                                             0.0003591
# Snow, Rain, Partially cloudy-Clear                                                                                     0.0000004
# Partially cloudy-Overcast                                                                                              0.1331884
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Overcast                                                        1.0000000
# Rain, Overcast-Overcast                                                                                                1.0000000
# Rain, Partially cloudy-Overcast                                                                                        0.3514049
# Snow, Overcast-Overcast                                                                                                0.8196339
# Snow, Partially cloudy-Overcast                                                                                        0.1944750
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Overcast                                                     0.9984926
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Overcast                                                          1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Overcast                                                  1.0000000
# Snow, Rain, Ice, Overcast-Overcast                                                                                     0.9999999
# Snow, Rain, Overcast-Overcast                                                                                          0.0351656
# Snow, Rain, Partially cloudy-Overcast                                                                                  0.0023283
# Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Partially cloudy                                                0.9999999
# Rain, Overcast-Partially cloudy                                                                                        0.0001621
# Rain, Partially cloudy-Partially cloudy                                                                                0.9991861
# Snow, Overcast-Partially cloudy                                                                                        0.0969512
# Snow, Partially cloudy-Partially cloudy                                                                                0.0000297
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Partially cloudy                                             0.9190413
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Partially cloudy                                                  0.9999593
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Partially cloudy                                          0.9999991
# Snow, Rain, Ice, Overcast-Partially cloudy                                                                             0.9998295
# Snow, Rain, Overcast-Partially cloudy                                                                                  0.0000000
# Snow, Rain, Partially cloudy-Partially cloudy                                                                          0.0000000
# Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                                  1.0000000
# Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                          1.0000000
# Snow, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                                  0.9999947
# Snow, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                          0.9999920
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy       0.9999988
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy            1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy    1.0000000
# Snow, Rain, Ice, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                       1.0000000
# Snow, Rain, Overcast-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                            0.9999916
# Snow, Rain, Partially cloudy-Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                    0.9999904
# Rain, Partially cloudy-Rain, Overcast                                                                                  0.0111765
# Snow, Overcast-Rain, Overcast                                                                                          0.6641053
# Snow, Partially cloudy-Rain, Overcast                                                                                  0.0395859
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Overcast                                               0.9963981
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Overcast                                                    1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Overcast                                            1.0000000
# Snow, Rain, Ice, Overcast-Rain, Overcast                                                                               0.9999997
# Snow, Rain, Overcast-Rain, Overcast                                                                                    0.0008721
# Snow, Rain, Partially cloudy-Rain, Overcast                                                                            0.0000004
# Snow, Overcast-Rain, Partially cloudy                                                                                  0.1431068
# Snow, Partially cloudy-Rain, Partially cloudy                                                                          0.0001134
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Rain, Partially cloudy                                       0.9417261
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Rain, Partially cloudy                                            0.9999817
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Rain, Partially cloudy                                    0.9999997
# Snow, Rain, Ice, Overcast-Rain, Partially cloudy                                                                       0.9999137
# Snow, Rain, Overcast-Rain, Partially cloudy                                                                            0.0000000
# Snow, Rain, Partially cloudy-Rain, Partially cloudy                                                                    0.0000000
# Snow, Partially cloudy-Snow, Overcast                                                                                  1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Overcast                                               1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Overcast                                                    1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Overcast                                            0.9999987
# Snow, Rain, Ice, Overcast-Snow, Overcast                                                                               1.0000000
# Snow, Rain, Overcast-Snow, Overcast                                                                                    1.0000000
# Snow, Rain, Partially cloudy-Snow, Overcast                                                                            1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast-Snow, Partially cloudy                                       1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Partially cloudy                                            1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Partially cloudy                                    0.9999980
# Snow, Rain, Ice, Overcast-Snow, Partially cloudy                                                                       1.0000000
# Snow, Rain, Overcast-Snow, Partially cloudy                                                                            1.0000000
# Snow, Rain, Partially cloudy-Snow, Partially cloudy                                                                    1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast         1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast 0.9999997
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                    1.0000000
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                         1.0000000
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Ice, Overcast                                 1.0000000
# Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast      1.0000000
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                         1.0000000
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                              1.0000000
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Overcast                                      1.0000000
# Snow, Rain, Ice, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                 1.0000000
# Snow, Rain, Overcast-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                                      0.9999979
# Snow, Rain, Partially cloudy-Snow, Rain, Freezing Drizzle/Freezing Rain, Partially cloudy                              0.9999976
# Snow, Rain, Overcast-Snow, Rain, Ice, Overcast                                                                         1.0000000
# Snow, Rain, Partially cloudy-Snow, Rain, Ice, Overcast                                                                 1.0000000
# Snow, Rain, Partially cloudy-Snow, Rain, Overcast                                                                      1.0000000

# %% [markdown]
# Multicollinearity

# %%
head(b)
# Out:
#   ...1 totalTrips totalCrimes X   name   tempmax tempmin temp feelslikemax
# 1 1    1496       239         166 boston 17.2    12.2    13.9 17.2
# 2 2    5119       251         167 boston 21.0    13.4    16.4 21.0
# 3 3    6246       226         168 boston 20.5    16.6    18.4 20.5
# 4 4    6124       285         169 boston 23.3    13.7    18.3 23.3
# 5 5    5803       276         170 boston 28.3    17.2    20.8 28.1
# 6 6    4797       246         171 boston 23.4    14.8    18.0 23.4
#   feelslikemin ⋯ sunset              moonphase conditions
# 1 12.2         ⋯ 2015-06-15 20:22:40 1.00      Rain, Overcast
# 2 13.4         ⋯ 2015-06-16 20:23:03 1.00      Rain, Overcast
# 3 16.6         ⋯ 2015-06-17 20:23:24 0.00      Partially cloudy
# 4 13.7         ⋯ 2015-06-18 20:23:44 0.02      Partially cloudy
# 5 17.2         ⋯ 2015-06-19 20:24:01 0.05      Partially cloudy
# 6 14.8         ⋯ 2015-06-20 20:24:16 0.08      Partially cloudy
#   description                                              icon
# 1 Cloudy skies throughout the day with rain.               rain
# 2 Cloudy skies throughout the day with early morning rain. rain
# 3 Partly cloudy throughout the day.                        partly-cloudy-day
# 4 Partly cloudy throughout the day.                        partly-cloudy-day
# 5 Partly cloudy throughout the day.                        partly-cloudy-day
# 6 Partly cloudy throughout the day.                        partly-cloudy-day
#   stations                                           Year Month DayName   Day
# 1 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 June  Monday    15
# 2 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 June  Tuesday   16
# 3 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 June  Wednesday 17
# 4 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 June  Thursday  18
# 5 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 June  Friday    19
# 6 KOWD,72509854704,KBED,KBOS,72509014739,72505914702 2015 June  Saturday  20

# %%
b$name <- NULL
b$tempmax <- NULL
b$tempmin <- NULL
b$moonphase <- NULL
b$sunset <- NULL
b$feelslikemax <- NULL
b$feelslikemin <- NULL
b$description <- NULL
b$icon <- NULL
b$severerisk <- NULL
b$sunrise <- NULL
b$solarradiation <- NULL
b$precipprob <- NULL
b$precipcover <- NULL
b$winddir <- NULL
b$sealevelpressure <- NULL
b$cloudcover <- NULL
b$solarenergy <- NULL
b$dew <- NULL
b$precip <- NULL
b$X <- NULL
b$preciptype <- NULL
b$snowdepth <- NULL
b$snow <- NULL
b$windgust <- NULL
b$stations <- NULL
b$windgust <- NULL





head(b)
# Out:
#   ...1 totalTrips totalCrimes temp feelslike humidity windspeed visibility
# 1 1    1496       239         13.9 13.9      87.2     25.5       9.3
# 2 2    5119       251         16.4 16.4      92.2     12.8       9.0
# 3 3    6246       226         18.4 18.4      60.4     31.1      16.0
# 4 4    6124       285         18.3 18.3      57.8     23.8      16.0
# 5 5    5803       276         20.8 20.8      66.9     25.5      16.0
# 6 6    4797       246         18.0 18.0      61.2     24.0      16.0
#   uvindex conditions       Year Month DayName   Day
# 1 4       Rain, Overcast   2015 June  Monday    15
# 2 7       Rain, Overcast   2015 June  Tuesday   16
# 3 9       Partially cloudy 2015 June  Wednesday 17
# 4 9       Partially cloudy 2015 June  Thursday  18
# 5 7       Partially cloudy 2015 June  Friday    19
# 6 8       Partially cloudy 2015 June  Saturday  20

# %%
b <- b[,-c(1)]
head(b)
# removing serial number column
# Out:
#   totalTrips totalCrimes temp feelslike humidity windspeed visibility uvindex
# 1 1496       239         13.9 13.9      87.2     25.5       9.3       4
# 2 5119       251         16.4 16.4      92.2     12.8       9.0       7
# 3 6246       226         18.4 18.4      60.4     31.1      16.0       9
# 4 6124       285         18.3 18.3      57.8     23.8      16.0       9
# 5 5803       276         20.8 20.8      66.9     25.5      16.0       7
# 6 4797       246         18.0 18.0      61.2     24.0      16.0       8
#   conditions       Year Month DayName   Day
# 1 Rain, Overcast   2015 June  Monday    15
# 2 Rain, Overcast   2015 June  Tuesday   16
# 3 Partially cloudy 2015 June  Wednesday 17
# 4 Partially cloudy 2015 June  Thursday  18
# 5 Partially cloudy 2015 June  Friday    19
# 6 Partially cloudy 2015 June  Saturday  20

# %%
b1<-b

# %%
# 
# removing conditions column too
# 
b1$conditions <- NULL

# %%
# b1$conditions <- gsub(","," ",b1$conditions)
head(b1)
# Out:
#   totalTrips totalCrimes temp feelslike humidity windspeed visibility uvindex
# 1 1496       239         13.9 13.9      87.2     25.5       9.3       4
# 2 5119       251         16.4 16.4      92.2     12.8       9.0       7
# 3 6246       226         18.4 18.4      60.4     31.1      16.0       9
# 4 6124       285         18.3 18.3      57.8     23.8      16.0       9
# 5 5803       276         20.8 20.8      66.9     25.5      16.0       7
# 6 4797       246         18.0 18.0      61.2     24.0      16.0       8
#   Year Month DayName   Day
# 1 2015 June  Monday    15
# 2 2015 June  Tuesday   16
# 3 2015 June  Wednesday 17
# 4 2015 June  Thursday  18
# 5 2015 June  Friday    19
# 6 2015 June  Saturday  20

# %%
m <- b1
# make all data types numeric
cols <- c("totalTrips", "totalCrimes", "temp","feelslike", "humidity", "windspeed", 
       "visibility", "uvindex","Year","Month","Day","DayName")
# month,dayname,conditions
m[,cols] <- m %>% select(all_of(cols)) %>% lapply(as.numeric)
# Dropping response variable (Y) for calculating Multicollinearity
mc <- m %>% select(-totalTrips, everything())

# %%
# step 3) correlate all the data
mc <- cor(m)
# sum(is.na(m)); sum(is.na(mc))

# Checking Variables that are highly correlated
highlyCorrelated = findCorrelation(mc, cutoff=0.7)
#Identifying Variable Names of Highly Correlated Variables
highlyCorCol = colnames(mc)[highlyCorrelated]
highlyCorCol
# Out:
# [1] "feelslike"

# %% [markdown]
# Check the Results using VIF

# %%
fit1 <- lm(totalTrips ~., data = b1); summary(fit1)
vif(fit1)
# Out:
# Call:
# lm(formula = totalTrips ~ ., data = b1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4989.8 -1109.9    10.2  1043.9 11279.5
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1899.3002   745.5028  -2.548  0.01091 *
# totalCrimes     3.1285     0.9618   3.253  0.00116 **
# temp          116.3218    65.0504   1.788  0.07388 .
# feelslike      34.3448    52.1386   0.659  0.51014
# humidity       -9.8378     4.0880  -2.406  0.01619 *
# windspeed     -33.2150     5.0258  -6.609 4.81e-11 ***
# visibility    138.6057    22.4320   6.179 7.63e-10 ***
# uvindex       153.8302    27.9424   5.505 4.10e-08 ***
# Year2016     1142.7789   166.8935   6.847 9.66e-12 ***
# Year2017     1539.8053   167.8616   9.173  < 2e-16 ***
# Year2018     3666.2266   235.8246  15.546  < 2e-16 ***
# Year2019     5438.1052   246.9389  22.022  < 2e-16 ***
# Year2020     3905.8111   186.2636  20.969  < 2e-16 ***
# Year2021     6034.7348   180.8294  33.373  < 2e-16 ***
# Year2022     8820.5655   192.8508  45.738  < 2e-16 ***
# Month.L      4065.3462   183.9761  22.097  < 2e-16 ***
# Month.Q     -2199.5061   289.4291  -7.599 4.33e-14 ***
# Month.C     -2636.3431   160.4951 -16.426  < 2e-16 ***
# Month^4      -660.9204   156.0190  -4.236 2.37e-05 ***
# Month^5       110.9383   145.6497   0.762  0.44633
# Month^6       725.1650   135.2933   5.360 9.17e-08 ***
# Month^7       905.1058   139.0210   6.511 9.20e-11 ***
# Month^8      -266.7987   132.9968  -2.006  0.04497 *
# Month^9      -709.9588   130.7399  -5.430 6.23e-08 ***
# Month^10     -408.0494   131.6294  -3.100  0.00196 **
# Month^11     -126.8345   130.7402  -0.970  0.33209
# DayName.L    -156.5561   102.4605  -1.528  0.12666
# DayName.Q    -658.0059   103.0970  -6.382 2.11e-10 ***
# DayName.C    -163.1210   102.0792  -1.598  0.11019
# DayName^4    -136.9078   101.5526  -1.348  0.17775
# DayName^5      82.4600   101.4108   0.813  0.41623
# DayName^6       4.7206   101.3047   0.047  0.96284
# Day02          -3.6326   298.3820  -0.012  0.99029
# Day03         174.1881   299.5777   0.581  0.56100
# Day04         209.6288   300.5597   0.697  0.48559
# Day05         110.3699   301.7649   0.366  0.71459
# Day06          74.8400   300.6457   0.249  0.80344
# Day07         275.5913   297.4743   0.926  0.35432
# Day08         285.2527   297.6808   0.958  0.33804
# Day09         145.4872   302.0888   0.482  0.63013
# Day10         489.7331   296.4460   1.652  0.09867 .
# Day11         448.7126   299.4227   1.499  0.13412
# Day12         309.8158   299.3644   1.035  0.30082
# Day13         273.0367   300.3572   0.909  0.36343
# Day14         527.9448   297.7995   1.773  0.07639 .
# Day15         537.4439   296.0477   1.815  0.06960 .
# Day16         495.8765   296.5184   1.672  0.09460 .
# Day17         378.4935   298.6762   1.267  0.20520
# Day18         404.2885   297.8493   1.357  0.17480
# Day19         193.9313   295.6912   0.656  0.51198
# Day20         114.2845   297.9986   0.384  0.70138
# Day21         281.2640   297.9463   0.944  0.34527
# Day22          17.1349   296.9526   0.058  0.95399
# Day23         222.2669   296.6482   0.749  0.45378
# Day24         310.7311   299.7338   1.037  0.29999
# Day25         177.1567   298.6056   0.593  0.55305
# Day26         121.2723   299.2485   0.405  0.68533
# Day27          79.8406   297.2910   0.269  0.78829
# Day28         -71.5339   298.7810  -0.239  0.81080
# Day29          -5.4210   302.7130  -0.018  0.98571
# Day30         138.4495   306.0848   0.452  0.65108
# Day31         428.6764   351.9404   1.218  0.22334
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1842 on 2257 degrees of freedom
# Multiple R-squared:  0.8242,	Adjusted R-squared:  0.8194
# F-statistic: 173.4 on 61 and 2257 DF,  p-value: < 2.2e-16
#             GVIF       Df GVIF^(1/(2*Df))
# totalCrimes   3.469982  1  1.862789
# temp        257.264686  1 16.039473
# feelslike   246.976159  1 15.715475
# humidity      2.782453  1  1.668069
# windspeed     1.380159  1  1.174802
# visibility    2.033886  1  1.426144
# uvindex       3.188091  1  1.785522
# Year          5.511500  7  1.129660
# Month        14.342211 11  1.128687
# DayName       1.095775  6  1.007651
# Day           1.134623 30  1.002107

# %% [markdown]
# Remove highly correlated variables

# %%
cols <- c("feelslike")
b1 <- b1 %>% select(everything(), - all_of(cols))
names(b1)
# Out:
#  [1] "totalTrips"  "totalCrimes" "temp"        "humidity"    "windspeed"
#  [6] "visibility"  "uvindex"     "Year"        "Month"       "DayName"
# [11] "Day"

# %% [markdown]
# Assessing Outliers

# %%
par(mfrow=c(4,1))
options(repr.plot.width=16, repr.plot.height=7)
boxplot(b1$totalTrips, col = "grey40", horizontal = T, main = "totalTrips") 
boxplot(b1$temp, col = "grey40", horizontal = T, main ="temp")
boxplot(b1$humidity, col = "grey40", horizontal = T, main = "humidity") 
boxplot(b1$windspeed, col = "grey40", horizontal = T, main = "windspeed") 
boxplot(b1$visibility, col = "grey40", horizontal = T, main = "visibility") 
boxplot(b1$uvindex, col = "grey40", horizontal = T, main ="uvindex")
boxplot(b1$humidity, col = "grey40", horizontal = T, main = "humidity") 
boxplot(b1$totalCrimes, col = "grey40", horizontal = T, main = "totalCrimes") 

par(mfrow=c(1,1))
# Out:
# Plot with title “windspeed”
# Plot with title “totalCrimes”

# %% [markdown]
# Removing Outliers

# %% [markdown]
# There are not much outliers (atleast for weather data)

# %% [markdown]
# Removing outliers for visibility

# %%
Q <- quantile(b1$visibility, probs=c(.25, .75), na.rm = T)
# this is the data inside of the boxplot
iqr <- IQR(b1$visibility, na.rm = T)

# remove the outlier beyond 1.5 * iqr for visibility
df <- b1 %>% filter(visibility > (Q[1] - 1.5*iqr) & 
                     visibility < (Q[2] + 1.5*iqr))  

# visualize the new dataset without outliers
par(mfrow=c(2,1))
options(repr.plot.width=16, repr.plot.height=6)
boxplot(b1$visibility, col = "grey40", horizontal = T, 
        main = "visibility - Before Removing Outliers")
boxplot(df$visibility, col = "thistle2", horizontal = T, 
        main = "visibility - After Removing Outliers")
par(mfrow=c(1,1))
# Out:
# Plot with title “visibility - After Removing Outliers”

# %% [markdown]
# Splitting the dataset into the Training set and Test set

# %%
set.seed(123)
split = sample.split(df$totalTrips, SplitRatio = 0.75)
training_set = subset(df, split == TRUE)
test_set = subset(df, split == FALSE)

# %%
m1 <- df %>% select(totalTrips, 
            temp, 
            humidity, 
            windspeed,
            visibility,
            uvindex,
            totalCrimes,
            
            ) %>% lm() 
   
summary(m1)
# Out:
# Call:
# lm(formula = .)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7896.1 -2062.2  -489.8  1445.8 18758.2
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1727.7477  2500.0871   0.691     0.49
# temp         344.8450     9.6375  35.782  < 2e-16 ***
# humidity     -40.5529     7.1084  -5.705 1.34e-08 ***
# windspeed    -44.5888     9.1023  -4.899 1.05e-06 ***
# visibility   573.5787   142.2722   4.032 5.76e-05 ***
# uvindex     -453.2290    41.0980 -11.028  < 2e-16 ***
# totalCrimes  -11.6584     0.9923 -11.748  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3155 on 1931 degrees of freedom
# Multiple R-squared:  0.4834,	Adjusted R-squared:  0.4818
# F-statistic: 301.2 on 6 and 1931 DF,  p-value: < 2.2e-16

# %%
# check anova for F value significance
anova(m1)
# Out:
#             Df   Sum Sq      Mean Sq     F value     Pr(>F)
# temp           1 14504173561 14504173561 1456.701327 5.512648e-238
# humidity       1   214190030   214190030   21.511801  3.752433e-06
# windspeed      1   310488252   310488252   31.183345  2.680236e-08
# visibility     1    55786254    55786254    5.602795  1.802998e-02
# uvindex        1  1535229800  1535229800  154.188122  4.072152e-34
# totalCrimes    1  1374309656  1374309656  138.026389  7.843139e-31
# Residuals   1931 19226699825     9956862          NA            NA

# %%
summary(m1)[9]
# Out:
# $adj.r.squared
# [1] 0.4818381

# %% [markdown]
# **Decision Tree Regression **

# %% [markdown]
# Fitting Decision Tree Regression to the dataset

# %%
m2 = rpart(formula = totalTrips ~ .,
           data = training_set,
           method = "anova")

# %%
par(mfrow = c(1,1))
prp(m2, main = "Decision Tree")
# Out:
# Plot with title “Decision Tree”

# %% [markdown]
#  Growing the Decision **Tree**

# %%
prn = rpart(formula = totalTrips ~ .,
            data = training_set,
            method = "anova")

# Print the Complexity Table 
printcp(prn)
# Out:
# Regression tree:
# rpart(formula = totalTrips ~ ., data = training_set, method = "anova")
#
# Variables actually used in tree construction:
# [1] Month temp  Year
#
# Root node error: 2.8485e+10/1453 = 19604100
#
# n= 1453
#
#         CP nsplit rel error  xerror      xstd
# 1 0.364365      0   1.00000 1.00125 0.0474593
# 2 0.264412      1   0.63564 0.64273 0.0336551
# 3 0.047587      2   0.37122 0.37960 0.0214132
# 4 0.046983      3   0.32364 0.35665 0.0200328
# 5 0.030219      4   0.27665 0.28437 0.0142147
# 6 0.029290      5   0.24643 0.26620 0.0136563
# 7 0.024879      6   0.21714 0.24454 0.0128862
# 8 0.011622      7   0.19227 0.20186 0.0096721
# 9 0.010000      8   0.18064 0.19319 0.0094198

# %% [markdown]
# pruning the tree

# %%
# using lowest complexity error from the cp table

ocp = prn$cptable[which.min(prn$cptable[,"xerror"]), "CP"]

m3 <- prune(prn, ocp)

# compare the before and after pruning models
par(mfrow = c(1,1))
prp(m3, main = "Model after Pruning")
# Out:
# Plot with title “Model after Pruning”

# %% [markdown]
# **Random Forest Regression  **

# %%
set.seed(1234)
m4 = rpart(formula = totalTrips ~ .,
           data = training_set,
           method = "anova")

prp(m4, main = "Random Forest Regression");
# Out:
# Plot with title “Random Forest Regression”

# %% [markdown]
# ## Support Vector Machines

# %%
m5 = svm(formula = totalTrips ~ .,
         data = training_set,
         type = 'eps-regression',
         kernel = 'linear')

summary(m5)
# Out:
# Call:
# svm(formula = totalTrips ~ ., data = training_set, type = "eps-regression",
#     kernel = "linear")
#
#
# Parameters:
#    SVM-Type:  eps-regression
#  SVM-Kernel:  linear
#        cost:  1
#       gamma:  0.01639344
#     epsilon:  0.1
#
#
# Number of Support Vectors:  1100

# %% [markdown]
# tuning the Model to Improve Accuracy

# %%
#sample the data
s1 = sample_frac(df, size = .3, replace = F)

# using 10 fold Cross Validation
t1 <- tune(svm, totalTrips ~ ., data = s1, 
           ranges = list(gamma = 2^(-1:1), cost = 2^(2:4)),
           tunecontrol = tune.control(sampling = "fix"))

# %%
# gamma as a sequence = seq(0.001, 1, length = 10)
t2 <- tune(svm, totalTrips ~ ., data = s1, 
           ranges = list(gamma = seq(0.001, 1, length = 10), 
                         cost = 2^(2:4)),
           tunecontrol = tune.control(sampling = "fix"))

# %% [markdown]
# applying the tuned SVM to the Training set

# %%
# apply the tuned paramemeters
m6 = svm(formula = totalTrips ~ .,
         data = training_set,
         type = 'eps-regression',
         kernel = 'radial',
         gamma = 0.5,
         cost = 0.1)

summary(m6)
# Out:
# Call:
# svm(formula = totalTrips ~ ., data = training_set, type = "eps-regression",
#     kernel = "radial", gamma = 0.5, cost = 0.1)
#
#
# Parameters:
#    SVM-Type:  eps-regression
#  SVM-Kernel:  radial
#        cost:  0.1
#       gamma:  0.5
#     epsilon:  0.1
#
#
# Number of Support Vectors:  1243

# %%
# apply the tuned paramemeters
m7 = svm(formula = totalTrips ~ .,
         data = training_set,
         type = 'eps-regression',
         kernel = 'radial',
         gamma = 0.112,
         cost = 0.1)

summary(m7)
# Out:
# Call:
# svm(formula = totalTrips ~ ., data = training_set, type = "eps-regression",
#     kernel = "radial", gamma = 0.112, cost = 0.1)
#
#
# Parameters:
#    SVM-Type:  eps-regression
#  SVM-Kernel:  radial
#        cost:  0.1
#       gamma:  0.112
#     epsilon:  0.1
#
#
# Number of Support Vectors:  1057

# %% [markdown]
# Predicting the Test set results

# %%
y_pred1 = predict(m1, newdata = test_set);
y_pred2 = predict(m2, newdata = test_set); 
y_pred3 = predict(m3, newdata = test_set);
y_pred4 = predict(m4, newdata = test_set); 
y_pred5 = predict(m5, newdata = test_set); 
y_pred6 = predict(m6, newdata = test_set); 
y_pred7 = predict(m7, newdata = test_set);

# %% [markdown]
# MSE, Variance , R Squared Value

# %%
#------ model 1  --------
MSE1 = sum((y_pred1 - test_set$totalTrips)^2)/nrow(test_set)
var.y1 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr1 = 1 - (MSE1/var.y1)

#------ model 2  --------
MSE2 = sum((y_pred2 - test_set$totalTrips)^2)/nrow(test_set)
var.y2 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr2 = 1 - (MSE2/var.y2)

#------ model 3  --------
MSE3 = sum((y_pred3 - test_set$totalTrips)^2)/nrow(test_set)
var.y3 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr3 = 1 - (MSE3/var.y3)

#------ model 4  --------
MSE4 = sum((y_pred4 - test_set$totalTrips)^2)/nrow(test_set)
var.y4 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr4 = 1 - (MSE4/var.y4)

#------ model 5  --------
MSE5 = sum((y_pred5 - test_set$totalTrips)^2)/nrow(test_set)
var.y5 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr5 = 1 - (MSE5/var.y5)

#------ model 6  --------
MSE6 = sum((y_pred6 - test_set$totalTrips)^2)/nrow(test_set)
var.y6 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr6 = 1 - (MSE6/var.y6)

#------ model 7  --------
MSE7 = sum((y_pred7 - test_set$totalTrips)^2)/nrow(test_set)
var.y7 = sum((test_set$totalTrips - mean(test_set$totalTrips))^2)/(nrow(test_set)-1)
Rsqr7 = 1 - (MSE7/var.y7)

# %% [markdown]
# Accuracy of Models

# %%
cat("\n Model 1 = ", MSE1, " Variance  = ", var.y1, "R Squared = ", Rsqr1);
cat("\n Model 2 = ", MSE2, " Variance  = ", var.y2, "R Squared = ", Rsqr2);
cat("\n Model 3 = ", MSE3, " Variance  = ", var.y3, "R Squared = ", Rsqr3);
cat("\n Model 4 = ", MSE4, " Variance  = ", var.y4, "R Squared = ", Rsqr4);
cat("\n Model 5 = ", MSE5, " Variance  = ", var.y5, "R Squared = ", Rsqr5);
cat("\n Model 6 = ", MSE6, " Variance  = ", var.y6, "R Squared = ", Rsqr6);
cat("\n Model 7 = ", MSE7, " Variance  = ", var.y7, "R Squared = ", Rsqr7);
# Out:
#  Model 1 =  9259653  Variance  =  18008206 R Squared =  0.4858092
#  Model 2 =  4070093  Variance  =  18008206 R Squared =  0.7739867
#  Model 3 =  4070093  Variance  =  18008206 R Squared =  0.7739867
#  Model 4 =  4070093  Variance  =  18008206 R Squared =  0.7739867
#  Model 5 =  3710096  Variance  =  18008206 R Squared =  0.7939775
#  Model 6 =  4118993  Variance  =  18008206 R Squared =  0.7712713
#  Model 7 =  4118993  Variance  =  18008206 R Squared =  0.7712713
